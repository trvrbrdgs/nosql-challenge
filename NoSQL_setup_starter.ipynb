# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from bson.objectid import ObjectId
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cc7cd83603de6111781f4c'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_penang= {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_penang)

# %%
# Check that the new restaurant was inserted
check = {'BusinessName':'Penang Flavours'}
results = establishments.find(check)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cc82238e8a34adc3bc177b'),
#  'geocode': {'latitude': Decimal128('51.49014200'),
#              'longitude': Decimal128('0.08384000')},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95dbe581082c395cff283'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query= {'BusinessType':'Restaurant/Cafe/Canteen'}
fields= {'BusinessType':1, 'BusinessType':1}
results= list(establishments.find(query, fields))
pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f4c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f57')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f5f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f60')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f75')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f7c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f7d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f81')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f98')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781f9a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fa0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fa4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fa5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fa8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781faa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781faf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fb0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fb1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fb2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fb9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fbb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fbc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fc3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fc4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fc5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fcc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fd5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fd6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fd8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fdc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fdd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fe0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fe1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fe5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fe9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781ff2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781ff3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781ff5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781ff9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781ffb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111781fff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782000')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782005')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782008')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178200a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782012')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782013')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782015')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178201d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178201e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178201f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782025')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782027')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782029')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178202b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782031')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782032')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782034')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782035')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782036')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782037')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178203a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de611178203f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782041')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782042')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd83603de6111782044')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782051')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782052')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782055')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782056')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782058')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178205e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178205f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782062')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782064')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782066')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782067')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178206d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782070')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782072')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782078')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782082')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178209a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178209e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117820f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782100')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782104')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782105')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782106')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782107')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782108')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782109')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178210b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178210c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178210e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782111')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782113')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782117')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782119')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782121')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782122')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782123')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782124')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782125')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782126')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178212b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178212c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782137')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782138')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178213a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178213b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178213d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178213f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782148')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178214c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178214e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782153')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782155')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178215a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178215c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178215d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782160')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782168')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178216e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782174')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782179')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178217c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178217e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782182')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782185')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782188')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782190')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782194')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782197')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782198')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178219a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178219b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178219f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821d5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117821ff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782201')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782203')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782208')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178220a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782211')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782213')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782220')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178222a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782232')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782237')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178223c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178223f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782247')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178224c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782253')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782254')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782256')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782259')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178225a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178225b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178225f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782262')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782267')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782274')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782275')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178227a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178227d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782284')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782287')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178228f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782297')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117822fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782302')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782306')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178232f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782330')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782332')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782336')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178233a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178233b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782341')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782343')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782348')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178234a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782351')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782352')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782354')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178235b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178236e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782370')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782372')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782376')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782377')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782382')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782385')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782386')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178238e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782394')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178239d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823b1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117823fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782401')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782406')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178240a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178240f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782410')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178241e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782421')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782422')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782424')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782426')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178242b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782433')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782435')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782436')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782437')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782438')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178243a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178243f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782440')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782441')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782442')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782444')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782449')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178244c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178244d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782452')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782454')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782455')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782459')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178245b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178245c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178245d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782462')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782467')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178246a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178246c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178246e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178246f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782470')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782471')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782473')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782474')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782477')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782478')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782479')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178247b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178247c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782481')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782485')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782486')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782487')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178248b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782490')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782491')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782494')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178249b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824dd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824fd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117824fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782504')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782505')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782506')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178250a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178251a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178251f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782526')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178252b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782534')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782535')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178253a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178253f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782541')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782542')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782544')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782546')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782547')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178254a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178254b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782556')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178255c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178256c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782570')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782578')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782589')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178258b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178258d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782590')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782591')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782597')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825dd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117825fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782600')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782605')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178260d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178260f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782612')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782613')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782618')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782619')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178261e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178261f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782623')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782627')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782628')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782629')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178262d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782630')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782631')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782634')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178263b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178263c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178263f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782640')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782642')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782643')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782645')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178264a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178264b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178264c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178264d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178264f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782650')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782651')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782653')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782654')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782655')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782656')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782659')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178265b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178265d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178265e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782660')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782663')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782664')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782667')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782668')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178266a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178266b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782670')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782671')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782672')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782674')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782676')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178267c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782685')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782687')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782688')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178268a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178268b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178268c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178268e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de611178268f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782690')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782692')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782695')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de6111782698')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7cd93603de61117826ce')},
# ...
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b559')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b55a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b55d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b562')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b565')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b567')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b569')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b574')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b57a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b57e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b57f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b582')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b588')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b589')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b58b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b594')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b595')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b598')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b59b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b59d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5dd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b5fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b600')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b601')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b602')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b603')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b604')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b606')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b60b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b60c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b616')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b617')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b61a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b61e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b624')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b627')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b62f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b630')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b631')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b63a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b65b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b663')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b667')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b66c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b66d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b66e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b670')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b673')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b675')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b676')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b677')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b678')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b679')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b68a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b68e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b69a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b69c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b6fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b703')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b705')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b707')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b70b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b714')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b717')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b719')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b71a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b71b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b71e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b720')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b721')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b722')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b725')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b727')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b728')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b729')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b72e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b72f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b730')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b732')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b733')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b735')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b736')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b737')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b738')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b73b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b740')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b741')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b746')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b748')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b74a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b74b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b750')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b754')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b757')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b75b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b767')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b76c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b76e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b76f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b774')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b775')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b782')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b78c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b78d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b795')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc7ce83603de611178b7c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63cc82238e8a34adc3bc177b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   '_id': ObjectId('63d95dbe581082c395cff283')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
update= establishments.update_one(
    {'BusinessName':'Penang Flavours'},
    {'$set':{'BusinessTypeID':1}}
)

# %%
# Confirm that the new restaurant was updated
check = {'BusinessName':'Penang Flavours'}
results = establishments.find(check)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cc82238e8a34adc3bc177b'),
#  'geocode': {'latitude': Decimal128('51.49014200'),
#              'longitude': Decimal128('0.08384000')},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95dbe581082c395cff283'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count= db.establishments.count_documents({'LocalAuthorityName':'Dover'})
pprint(dover_count)
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
del_dover= db.establishments.delete_many({'LocalAuthorityName':'Dover'})

# %%
# Check if any remaining documents include Dover
dover_count= db.establishments.count_documents({'LocalAuthorityName':'Dover'})
pprint(dover_count)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cc7cd83603de6111781f4c'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
long_change = establishments.update_many({}, [
                                                {'$set':
                                                        {"geocode.longitude":
                                                            {'$toDecimal': "$geocode.longitude"}
                                                        }
                                                }
                                            ]
                                      )

# %%
# Change the data type from String to Decimal for latitude
lat_change = establishments.update_many({}, [
                                                {'$set':
                                                        {"geocode.latitude":
                                                            {'$toDecimal': "$geocode.latitude"}
                                                        }
                                                }
                                            ]
                                      )

# %%
# Check that the coordinates are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cc7cd83603de6111781f4c'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
